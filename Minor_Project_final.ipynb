# %% [markdown]
# # **General**

# %%
# Imports
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Laoading data from local drive**

# %% [markdown]
# # **Read Data**

# %%
fd = pd.read_csv('Fertilizer.csv')
td = pd.read_csv('final_temperature.csv')
rd = pd.read_csv('final_rainfall.csv')
ytr= pd.read_csv('Final_Dataset_after_temperature.csv')

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Fertilizer Data**

# %%
fd
# Out:
#       Unnamed: 0              Crop    N   P   K    pH
# 0              0              Rice   80  40  40  5.50
# 1              1    Jowar(Sorghum)   80  40  40  5.50
# 2              2       Barley(JAV)   70  40  45  5.50
# 3              3             Maize   80  40  20  5.50
# 4              4  Ragi( naachnnii)   50  40  20  5.50
# ...          ...               ...  ...  ..  ..   ...
# 1838        1838       Lemon Grass   25  40  40  5.32
# 1839        1839            Cotton  120  40  20  5.32
# 1840        1840              Jute   80  40  40  5.32
# 1841        1841            Coffee  100  20  30  5.32
# 1842        1842         Sunflower   50  60  30  5.32
#
# [1843 rows x 6 columns]

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1843 entries, 0 to 1842
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1843 non-null   int64
#  1   Crop        1843 non-null   object
#  2   N           1843 non-null   int64
#  3   P           1843 non-null   int64
#  4   K           1843 non-null   int64
#  5   pH          1843 non-null   float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 86.5+ KB

# %%
fd.describe()
# Out:
#         Unnamed: 0            N            P            K           pH
# count  1843.000000  1843.000000  1843.000000  1843.000000  1843.000000
# mean    921.000000    59.896907    43.453608    45.463918     5.588660
# std     532.172591    36.328744    27.065517    36.130181     0.755267
# min       0.000000    10.000000    10.000000    10.000000     2.920000
# 25%     460.500000    20.000000    20.000000    20.000000     5.080000
# 50%     921.000000    50.000000    40.000000    40.000000     5.560000
# 75%    1381.500000    90.000000    60.000000    60.000000     6.320000
# max    1842.000000   180.000000   125.000000   200.000000     6.680000

# %%
# Number of crops
len(fd['Crop'].unique())
# Out:
# 97

# %% [markdown]
# ## **Temperature Data**

# %%
td
# Out:
#                          States  kharif_temp  rabi_temp  summer_temp  \
# 0                         bihar    33.583333     23.106    34.923333
# 1                     meghalaya    22.070000     15.852    20.363333
# 2                        punjab    34.730000     20.312    31.250000
# 3                madhya pradesh    30.430000     23.562    35.343333
# 4                           goa    27.316667     28.474    30.303333
# 5                     rajasthan    33.373333     22.766    33.350000
# 6                     telangana    28.680000     25.574    35.010000
# 7                       gujarat    30.616667     27.276    33.763333
# 8        dadra and nagar haveli    28.223333     27.016    30.063333
# 9                 uttar pradesh    34.010000     22.676    34.666667
# 10                      mizoram    26.646667     21.482    27.743333
# 11                       kerala    27.000000     27.600    29.333333
# 12                      manipur    27.233333     23.140    29.600000
# 13                  uttarakhand    25.666667     14.600    23.133333
# 14                       odisha    28.500000     23.560    30.266667
# 15                  west bengal    28.333333     22.280    29.200000
# 16             himachal pradesh    22.033333     10.380    17.500000
# 17            arunachal pradesh    11.200000      1.180     4.800000
# 18                   tamil nadu    29.566667     25.440    29.433333
# 19                   chandigarh    28.700000     16.820    26.533333
# 20                   puducherry    29.400000     25.760    29.000000
# 21  andaman and nicobar islands    27.000000     26.600    27.800000
# 22                        assam    27.333333     20.800    25.033333
# 23                  maharashtra    26.366667     25.600    27.966667
# 24                       sikkim    20.100000     12.500    16.333333
# 25                      tripura    27.266667     21.660    26.866667
# 26                    karnataka    22.600000     21.300    25.833333
# 27                      haryana    35.346667     21.704    33.006667
# 28                 chhattisgarh    28.033333     22.380    31.900000
# 29                     nagaland    26.433333     18.920    23.400000
# 30               andhra pradesh    29.266667     25.460    31.266667
# 31                    jharkhand    25.666667     18.580    27.433333
# 32            jammu and kashmir    27.866667     14.700    23.566667
#
#     yearly_temp
# 0     29.186364
# 1     18.778182
# 2     27.227273
# 3     28.648182
# 4     28.657273
# 5     28.545455
# 6     28.994545
# 7     29.956364
# 8     28.176364
# 9     29.037273
# 10    24.598182
# 11    27.909091
# 12    26.018182
# 13    19.945455
# 14    26.736364
# 15    25.818182
# 16    15.500000
# 17     4.900000
# 18    27.654545
# 19    22.709091
# 20    27.636364
# 21    27.036364
# 22    23.736364
# 23    26.454545
# 24    15.618182
# 25    24.609091
# 26    22.890909
# 27    28.507273
# 28    26.518182
# 29    22.190909
# 30    28.081818
# 31    22.927273
# 32    20.709091

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   States       33 non-null     object
#  1   kharif_temp  33 non-null     float64
#  2   rabi_temp    33 non-null     float64
#  3   summer_temp  33 non-null     float64
#  4   yearly_temp  33 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.4+ KB

# %%
td.describe()
# Out:
#        kharif_temp  rabi_temp  summer_temp  yearly_temp
# count    33.000000  33.000000    33.000000    33.000000
# mean     27.593737  21.183636    27.757172    24.724628
# std       4.598216   5.743573     6.287774     5.221474
# min      11.200000   1.180000     4.800000     4.900000
# 25%      26.433333  18.920000    25.833333    22.890909
# 50%      27.866667  22.380000    29.200000    26.518182
# 75%      29.400000  25.460000    31.266667    28.176364
# max      35.346667  28.474000    35.343333    29.956364

# %%
# Number of Indian States and Union Territories
len(td['States'].unique())
# Out:
# 33

# %%
td.shape
# Out:
# (33, 5)

# %%
# Number of crops
len(fd['Crop'].unique())
# Out:
# 97

# %% [markdown]
# ## **Rainfall Data**

# %%
rd
# Out:
#     yearly_rainfall  kharif_rainfall  rabi_rainfall  summer_rainfall
# 0         3322.0600        1925.6800     865.940000       530.440000
# 1         2569.5200        1712.6600     241.780000       615.080000
# 2         2169.3200        1543.7600     127.680000       497.880000
# 3         1778.8800        1220.2200     145.760000       412.900000
# 4         2459.6400        1875.6000     140.520000       443.520000
# 5         1501.9800        1166.9400     152.540000       182.500000
# 6         1426.3000        1145.2200     167.380000       113.700000
# 7         1186.2800         976.0600     122.420000        87.800000
# 8         1026.6400         840.4600      87.200000        98.980000
# 9          689.8800         579.7500      75.320000        34.810000
# 10        1411.7800        1110.7800     169.820000       131.180000
# 11         421.1400         331.8800      41.300000        47.960000
# 12         535.7800         411.5200      66.520000        57.740000
# 13        1098.2600         664.9400     240.100000       193.220000
# 14        1089.6000         516.6800     293.360000       279.560000
# 15         556.2000         510.0500      19.380000        26.770000
# 16        1111.6800        1011.4900      73.470000        26.720000
# 17         810.2600         790.9800      15.340000         3.940000
# 18        3041.4000        2879.8600     141.460000        20.080000
# 19         714.6800         607.4800      70.110000        37.090000
# 20        1299.2600        1151.0200      94.020000        54.220000
# 21        1037.3200         654.3400     288.300000        94.680000
# 22         942.8000         770.4400      98.940000        73.420000
# 23         884.5000         297.6600     446.140000       140.700000
# 24        1603.2375        1246.7150     199.212500       157.310000
# 25        2817.8600        1997.1200     490.740000       330.000000
# 26        1050.2450         423.7450      56.236000       110.023000
# 27        1350.0250         702.4590      40.023000       143.023456
# 28          35.2140          80.9260       9.627044        17.856023
# 29         560.1245         168.2570       5.274000        12.987422
# 30         550.1245         162.7200      10.265748         3.274569
# 31         700.2410         207.5500      70.598000        12.520000
# 32         742.0124         235.4251      85.243160        12.452100

# %%
rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   yearly_rainfall  33 non-null     float64
#  1   kharif_rainfall  33 non-null     float64
#  2   rabi_rainfall    33 non-null     float64
#  3   summer_rainfall  33 non-null     float64
# dtypes: float64(4)
# memory usage: 1.2 KB

# %%
rd.describe()
# Out:
#        yearly_rainfall  kharif_rainfall  rabi_rainfall  summer_rainfall
# count        33.000000        33.000000      33.000000        33.000000
# mean       1287.704361       906.678397     156.121802       151.646563
# std         798.628289       641.690354     172.206324       170.155753
# min          35.214000        80.926000       5.274000         3.274569
# 25%         714.680000       423.745000      66.520000        26.770000
# 50%        1089.600000       770.440000      98.940000        94.680000
# 75%        1501.980000      1166.940000     169.820000       182.500000
# max        3322.060000      2879.860000     865.940000       615.080000

# %%
rd.shape
# Out:
# (33, 4)

# %% [markdown]
# ## **Crop Yield Data Using Temperature and Rainfall**

# %%
ytr
# Out:
#             State_Name   Crop_Type          Crop  rainfall  temperature  \
# 0       andhra pradesh      kharif     Arhar/Tur    654.34    29.266667
# 1       andhra pradesh      kharif         Bajra    654.34    29.266667
# 2       andhra pradesh      kharif   Castor seed    654.34    29.266667
# 3       andhra pradesh      kharif  Cotton(lint)    654.34    29.266667
# 4       andhra pradesh      kharif  Dry chillies    654.34    29.266667
# ...                ...         ...           ...       ...          ...
# 173021     west bengal      summer         Maize    182.50    29.200000
# 173022     west bengal      summer          Rice    182.50    29.200000
# 173023     west bengal  whole year     Sugarcane   1501.98    25.818182
# 173024     west bengal        rabi          Rice    152.54    22.280000
# 173025     west bengal        rabi       Sesamum    152.54    22.280000
#
#         Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0                21400.0              2600.0           0.121495
# 1                 1400.0               500.0           0.357143
# 2                 1000.0               100.0           0.100000
# 3                 7300.0              9400.0           1.287671
# 4                 3700.0              7100.0           1.918919
# ...                  ...                 ...                ...
# 173021             258.0               391.0           1.515504
# 173022             105.0               281.0           2.676190
# 173023             303.0             11541.0          38.089109
# 173024          152676.0            261435.0           1.712352
# 173025             244.0                95.0           0.389344
#
# [173026 rows x 8 columns]

# %%
ytr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173026 entries, 0 to 173025
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   State_Name          173026 non-null  object
#  1   Crop_Type           173026 non-null  object
#  2   Crop                173026 non-null  object
#  3   rainfall            173026 non-null  float64
#  4   temperature         173026 non-null  float64
#  5   Area_in_hectares    173026 non-null  float64
#  6   Production_in_tons  173026 non-null  float64
#  7   Yield_ton_per_hec   173026 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 10.6+ MB

# %%
ytr.describe()
# Out:
#             rainfall    temperature  Area_in_hectares  Production_in_tons  \
# count  173026.000000  173026.000000      1.730260e+05        1.730260e+05
# mean      684.278217      26.631503      1.360911e+04        4.911717e+04
# std       585.993896       4.913924      5.670028e+04        4.039047e+05
# min         3.274569       1.180000      2.000000e-01        0.000000e+00
# 25%       152.540000      22.890909      1.200000e+02        1.170000e+02
# 50%       579.750000      27.333333      8.320000e+02        9.790000e+02
# 75%      1037.320000      29.266667      5.800000e+03        8.422000e+03
# max      3322.060000      35.346667      8.580100e+06        3.715800e+07
#
#        Yield_ton_per_hec
# count      173026.000000
# mean            4.747889
# std            31.626828
# min             0.000000
# 25%             0.500660
# 50%             0.985768
# 75%             2.244290
# max          9801.000000

# %%
ytr.shape
# Out:
# (173026, 8)

# %%
ytr
# Out:
#             State_Name   Crop_Type          Crop  rainfall  temperature  \
# 0       andhra pradesh      kharif     Arhar/Tur    654.34    29.266667
# 1       andhra pradesh      kharif         Bajra    654.34    29.266667
# 2       andhra pradesh      kharif   Castor seed    654.34    29.266667
# 3       andhra pradesh      kharif  Cotton(lint)    654.34    29.266667
# 4       andhra pradesh      kharif  Dry chillies    654.34    29.266667
# ...                ...         ...           ...       ...          ...
# 173021     west bengal      summer         Maize    182.50    29.200000
# 173022     west bengal      summer          Rice    182.50    29.200000
# 173023     west bengal  whole year     Sugarcane   1501.98    25.818182
# 173024     west bengal        rabi          Rice    152.54    22.280000
# 173025     west bengal        rabi       Sesamum    152.54    22.280000
#
#         Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0                21400.0              2600.0           0.121495
# 1                 1400.0               500.0           0.357143
# 2                 1000.0               100.0           0.100000
# 3                 7300.0              9400.0           1.287671
# 4                 3700.0              7100.0           1.918919
# ...                  ...                 ...                ...
# 173021             258.0               391.0           1.515504
# 173022             105.0               281.0           2.676190
# 173023             303.0             11541.0          38.089109
# 173024          152676.0            261435.0           1.712352
# 173025             244.0                95.0           0.389344
#
# [173026 rows x 8 columns]

# %%
# Number of crops
len(ytr['Crop'].unique())
# Out:
# 114

# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# ## **Tempertaure Data**

# %%
td
# Out:
#                          States  kharif_temp  rabi_temp  summer_temp  \
# 0                         bihar    33.583333     23.106    34.923333
# 1                     meghalaya    22.070000     15.852    20.363333
# 2                        punjab    34.730000     20.312    31.250000
# 3                madhya pradesh    30.430000     23.562    35.343333
# 4                           goa    27.316667     28.474    30.303333
# 5                     rajasthan    33.373333     22.766    33.350000
# 6                     telangana    28.680000     25.574    35.010000
# 7                       gujarat    30.616667     27.276    33.763333
# 8        dadra and nagar haveli    28.223333     27.016    30.063333
# 9                 uttar pradesh    34.010000     22.676    34.666667
# 10                      mizoram    26.646667     21.482    27.743333
# 11                       kerala    27.000000     27.600    29.333333
# 12                      manipur    27.233333     23.140    29.600000
# 13                  uttarakhand    25.666667     14.600    23.133333
# 14                       odisha    28.500000     23.560    30.266667
# 15                  west bengal    28.333333     22.280    29.200000
# 16             himachal pradesh    22.033333     10.380    17.500000
# 17            arunachal pradesh    11.200000      1.180     4.800000
# 18                   tamil nadu    29.566667     25.440    29.433333
# 19                   chandigarh    28.700000     16.820    26.533333
# 20                   puducherry    29.400000     25.760    29.000000
# 21  andaman and nicobar islands    27.000000     26.600    27.800000
# 22                        assam    27.333333     20.800    25.033333
# 23                  maharashtra    26.366667     25.600    27.966667
# 24                       sikkim    20.100000     12.500    16.333333
# 25                      tripura    27.266667     21.660    26.866667
# 26                    karnataka    22.600000     21.300    25.833333
# 27                      haryana    35.346667     21.704    33.006667
# 28                 chhattisgarh    28.033333     22.380    31.900000
# 29                     nagaland    26.433333     18.920    23.400000
# 30               andhra pradesh    29.266667     25.460    31.266667
# 31                    jharkhand    25.666667     18.580    27.433333
# 32            jammu and kashmir    27.866667     14.700    23.566667
#
#     yearly_temp
# 0     29.186364
# 1     18.778182
# 2     27.227273
# 3     28.648182
# 4     28.657273
# 5     28.545455
# 6     28.994545
# 7     29.956364
# 8     28.176364
# 9     29.037273
# 10    24.598182
# 11    27.909091
# 12    26.018182
# 13    19.945455
# 14    26.736364
# 15    25.818182
# 16    15.500000
# 17     4.900000
# 18    27.654545
# 19    22.709091
# 20    27.636364
# 21    27.036364
# 22    23.736364
# 23    26.454545
# 24    15.618182
# 25    24.609091
# 26    22.890909
# 27    28.507273
# 28    26.518182
# 29    22.190909
# 30    28.081818
# 31    22.927273
# 32    20.709091

# %%
temp_data = td.groupby('States')['yearly_temp'].mean()  # Group by 'States' and get mean of 'yearly_temp'

# Plot data
fig, ax = plt.subplots(figsize=(15, 9))
fig.suptitle('Mean Yearly Temperature (°C) Across States')

temp_data.plot(ax=ax, kind='bar')  # Plot as bar graph (adjust 'kind' for different plot types)

ax.set_ylabel('Mean Yearly Temperature (°C)')
ax.set_xlabel('States')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability with many states

plt.show()

# %%
td=td.corr()
td
# Out:
# <ipython-input-202-59282da27dfa>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   td=td.corr()
#              kharif_temp  rabi_temp  summer_temp  yearly_temp
# kharif_temp     1.000000   0.673434     0.897919     0.871784
# rabi_temp       0.673434   1.000000     0.855821     0.942807
# summer_temp     0.897919   0.855821     1.000000     0.971985
# yearly_temp     0.871784   0.942807     0.971985     1.000000

# %%
sns.heatmap(td,annot=True,cbar=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.distplot(td['yearly_temp'])
plt.show()
# Out:
# <ipython-input-204-bb3a4d32400a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(td['yearly_temp'])

# %% [markdown]
# ## **Rainfall Data**

# %%
rd=rd.corr()
rd
# Out:
#                  yearly_rainfall  kharif_rainfall  rabi_rainfall  \
# yearly_rainfall         1.000000         0.936817       0.637942
# kharif_rainfall         0.936817         1.000000       0.443035
# rabi_rainfall           0.637942         0.443035       1.000000
# summer_rainfall         0.744926         0.569931       0.593002
#
#                  summer_rainfall
# yearly_rainfall         0.744926
# kharif_rainfall         0.569931
# rabi_rainfall           0.593002
# summer_rainfall         1.000000

# %%
sns.heatmap(rd,annot=True,cbar=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.distplot(rd['yearly_rainfall'])
plt.show()
# Out:
# <ipython-input-207-146fbd04ce77>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(rd['yearly_rainfall'])

# %% [markdown]
# ## **Final Crop Yield**

# %%
ytr
# Out:
#             State_Name   Crop_Type          Crop  rainfall  temperature  \
# 0       andhra pradesh      kharif     Arhar/Tur    654.34    29.266667
# 1       andhra pradesh      kharif         Bajra    654.34    29.266667
# 2       andhra pradesh      kharif   Castor seed    654.34    29.266667
# 3       andhra pradesh      kharif  Cotton(lint)    654.34    29.266667
# 4       andhra pradesh      kharif  Dry chillies    654.34    29.266667
# ...                ...         ...           ...       ...          ...
# 173021     west bengal      summer         Maize    182.50    29.200000
# 173022     west bengal      summer          Rice    182.50    29.200000
# 173023     west bengal  whole year     Sugarcane   1501.98    25.818182
# 173024     west bengal        rabi          Rice    152.54    22.280000
# 173025     west bengal        rabi       Sesamum    152.54    22.280000
#
#         Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0                21400.0              2600.0           0.121495
# 1                 1400.0               500.0           0.357143
# 2                 1000.0               100.0           0.100000
# 3                 7300.0              9400.0           1.287671
# 4                 3700.0              7100.0           1.918919
# ...                  ...                 ...                ...
# 173021             258.0               391.0           1.515504
# 173022             105.0               281.0           2.676190
# 173023             303.0             11541.0          38.089109
# 173024          152676.0            261435.0           1.712352
# 173025             244.0                95.0           0.389344
#
# [173026 rows x 8 columns]

# %%
ytr.boxplot()
# Out:
# <Axes: >

# %%
# Group by 'State_Name' and get mean of 'Yield_ton_per_hec'
crop_data_by_state = ytr.groupby('State_Name')['Yield_ton_per_hec'].mean()
crop_data_by_state
# Out:
# State_Name
# andaman and nicobar islands     3.985716
# andhra pradesh                  5.617801
# arunachal pradesh               3.435958
# assam                           3.850930
# bihar                           3.627812
# chandigarh                      8.212870
# chhattisgarh                    2.173884
# dadra and nagar haveli          5.828703
# goa                             8.256726
# gujarat                         6.104178
# haryana                         7.345785
# himachal pradesh                1.971346
# jammu and kashmir               1.482430
# jharkhand                       2.734009
# karnataka                       4.306220
# kerala                          7.370801
# madhya pradesh                  3.054928
# maharashtra                     5.511602
# manipur                         4.590515
# meghalaya                       2.930543
# mizoram                         2.293965
# nagaland                        3.473256
# odisha                          3.684726
# puducherry                      9.129335
# punjab                          7.257222
# rajasthan                       2.888783
# sikkim                          1.426699
# tamil nadu                     12.908846
# telangana                       4.671910
# tripura                         5.119187
# uttar pradesh                   5.309732
# uttarakhand                     3.448215
# west bengal                     4.931359
# Name: Yield_ton_per_hec, dtype: float64

# %%
crop_data_by_state = ytr.groupby('State_Name')['Yield_ton_per_hec'].mean()

# 1. Scatter Plot using matplotlib:
plt.figure(figsize=(15, 9))
plt.scatter(crop_data_by_state.index, crop_data_by_state.values)
plt.xlabel('State Name')
plt.ylabel('Mean Yield (tons per hectare)')
plt.title('Mean Yield per State (Scatter Plot)')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# 2. Box Plot using matplotlib:
plt.figure(figsize=(15, 9))
plt.boxplot(
    [ytr[ytr['State_Name'] == state]['Yield_ton_per_hec'] for state in ytr['State_Name'].unique()],
    labels=ytr['State_Name'].unique(),
    vert=False  # Horizontal box plot for better readability with many states
)
plt.xlabel('Yield (tons per hectare)')
plt.ylabel('State Name')
plt.title('Distribution of Yield per State (Box Plot)')
plt.show()

# %%
ytr1=ytr.corr()
ytr1
# Out:
# <ipython-input-212-60dddfa72f17>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ytr1=ytr.corr()
#                     rainfall  temperature  Area_in_hectares  \
# rainfall            1.000000     0.026452         -0.071972
# temperature         0.026452     1.000000          0.013094
# Area_in_hectares   -0.071972     0.013094          1.000000
# Production_in_tons -0.003863     0.023310          0.233366
# Yield_ton_per_hec   0.054478     0.011015         -0.008642
#
#                     Production_in_tons  Yield_ton_per_hec
# rainfall                     -0.003863           0.054478
# temperature                   0.023310           0.011015
# Area_in_hectares              0.233366          -0.008642
# Production_in_tons            1.000000           0.286510
# Yield_ton_per_hec             0.286510           1.000000

# %%
sns.heatmap(ytr1,annot=True,cbar=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.distplot(ytr1['Yield_ton_per_hec'])
plt.show()
# Out:
# <ipython-input-214-26c82b6d77cf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ytr1['Yield_ton_per_hec'])

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## **Removal of Outliers(Box Plot)**

# %%
ytr.boxplot(column='Production_in_tons')
plt.show()

# %%
def remove_outlier(col):

   sorted(col)

   q1,q3=col.quantile([0.25,0.75])

   IQR=q3-q1

   lwr_bound= q1-(1.5*IQR)

   upr_bound =q3+(1.5*IQR)

   return lwr_bound, upr_bound

# %%
low, high=remove_outlier(ytr["Production_in_tons"])

# %%
ytr["Production_in_tons"]=np.where(ytr["Production_in_tons"]>high, high, ytr["Production_in_tons"])

# %%
ytr["Production_in_tons"]=np.where (ytr["Production_in_tons"]<low, low, ytr ["Production_in_tons"])

# %%
ytr.boxplot(column="Production_in_tons")
# Out:
# <Axes: >

# %%
ytr.boxplot(column='Area_in_hectares')
plt.show()

# %%
low, high=remove_outlier(ytr["Area_in_hectares"])

# %%
ytr["Area_in_hectares"]=np.where(ytr["Area_in_hectares"]>high, high, ytr["Area_in_hectares"])

# %%
ytr["Area_in_hectares"]=np.where (ytr["Area_in_hectares"]<low, low, ytr ["Area_in_hectares"])

# %%
ytr.boxplot(column="Area_in_hectares")
# Out:
# <Axes: >

# %%
ytr.boxplot(column='Yield_ton_per_hec')
plt.show()

# %%
low, high=remove_outlier(ytr["Yield_ton_per_hec"])

# %%
ytr["Yield_ton_per_hec"]=np.where(ytr["Yield_ton_per_hec"]>high, high, ytr["Yield_ton_per_hec"])

# %%
ytr["Yield_ton_per_hec"]=np.where (ytr["Yield_ton_per_hec"]<low, low, ytr ["Yield_ton_per_hec"])

# %%
ytr.boxplot(column="Yield_ton_per_hec")
# Out:
# <Axes: >

# %%
low, high=remove_outlier(ytr["rainfall"])

# %%
ytr["rainfall"]=np.where(ytr["rainfall"]>high, high, ytr["rainfall"])

# %%
ytr["rainfall"]=np.where (ytr["rainfall"]<low, low, ytr ["rainfall"])

# %%
ytr.boxplot(column="rainfall")
# Out:
# <Axes: >

# %%
ytr.boxplot(column="temperature")
# Out:
# <Axes: >

# %%
low, high=remove_outlier(ytr["temperature"])

# %%
ytr["temperature"]=np.where(ytr["temperature"]>high, high, ytr["temperature"])

# %%
ytr["temperature"]=np.where (ytr["temperature"]<low, low, ytr ["temperature"])

# %%
ytr.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## **Removal of Missing Values**

# %%
ytr.shape
# Out:
# (173026, 8)

# %%
ytr
# Out:
#             State_Name   Crop_Type          Crop  rainfall  temperature  \
# 0       andhra pradesh      kharif     Arhar/Tur    654.34    29.266667
# 1       andhra pradesh      kharif         Bajra    654.34    29.266667
# 2       andhra pradesh      kharif   Castor seed    654.34    29.266667
# 3       andhra pradesh      kharif  Cotton(lint)    654.34    29.266667
# 4       andhra pradesh      kharif  Dry chillies    654.34    29.266667
# ...                ...         ...           ...       ...          ...
# 173021     west bengal      summer         Maize    182.50    29.200000
# 173022     west bengal      summer          Rice    182.50    29.200000
# 173023     west bengal  whole year     Sugarcane   1501.98    25.818182
# 173024     west bengal        rabi          Rice    152.54    22.280000
# 173025     west bengal        rabi       Sesamum    152.54    22.280000
#
#         Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0                14320.0              2600.0           0.121495
# 1                 1400.0               500.0           0.357143
# 2                 1000.0               100.0           0.100000
# 3                 7300.0              9400.0           1.287671
# 4                 3700.0              7100.0           1.918919
# ...                  ...                 ...                ...
# 173021             258.0               391.0           1.515504
# 173022             105.0               281.0           2.676190
# 173023             303.0             11541.0           4.859736
# 173024           14320.0             20879.5           1.712352
# 173025             244.0                95.0           0.389344
#
# [173026 rows x 8 columns]

# %%
X=ytr.drop("Yield_ton_per_hec",axis=1)
y=ytr["Yield_ton_per_hec"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (138420, 7)

# %%
y_train.shape
# Out:
# (138420,)

# %%
X_test.shape
# Out:
# (34606, 7)

# %%
y_test.shape
# Out:
# (34606,)

# %%
X_train
# Out:
#             State_Name Crop_Type                Crop  rainfall  temperature  \
# 122122     uttarakhand      rabi               Wheat  169.8200    14.600000
# 59473          haryana    kharif                Rice  331.8800    35.346667
# 30651      west bengal      rabi               Wheat  152.5400    22.280000
# 29995    uttar pradesh      rabi              Barley   75.3200    22.676000
# 41803    uttar pradesh    kharif             Sesamum  579.7500    34.010000
# ...                ...       ...                 ...       ...          ...
# 97639      west bengal      rabi   Moong(Green Gram)  152.5400    22.280000
# 95939          tripura      rabi  Other  Rabi pulses  145.7600    21.660000
# 152315       karnataka      rabi  Other  Rabi pulses  199.2125    21.300000
# 117952          odisha      rabi           Sugarcane  167.3800    23.560000
# 43567   andhra pradesh    kharif        Dry chillies  654.3400    29.266667
#
#         Area_in_hectares  Production_in_tons
# 122122           14320.0             20879.5
# 59473            14320.0             20879.5
# 30651              785.0              1461.0
# 29995             6125.0              9569.0
# 41803              151.0                24.0
# ...                  ...                 ...
# 97639               25.0                12.0
# 95939              305.0               177.0
# 152315             695.0               192.0
# 117952             411.0             20879.5
# 43567            14320.0             20879.5
#
# [138420 rows x 7 columns]

# %%
X_train.head(1)
# Out:
#          State_Name Crop_Type   Crop  rainfall  temperature  Area_in_hectares  \
# 122122  uttarakhand      rabi  Wheat    169.82         14.6           14320.0
#
#         Production_in_tons
# 122122             20879.5

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
ohe = OneHotEncoder(drop='first')
scale = StandardScaler()

preprocesser = ColumnTransformer(
        transformers = [
            ('StandardScale', scale, [3, 4, 5, 6]),
            ('OHE', ohe, [0, 1, 2]),
        ],
        remainder='passthrough'
)

# %%
preprocesser
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('StandardScale', StandardScaler(),
#                                  [3, 4, 5, 6]),
#                                 ('OHE', OneHotEncoder(drop='first'),
#                                  [0, 1, 2])])

# %%
X_train_dummy = preprocesser.fit_transform(X_train)
X_test_dummy = preprocesser.transform(X_test)

# %%
X_train_dummy
# Out:
# <138420x152 sparse matrix of type '<class 'numpy.float64'>'
# 	with 912053 stored elements in Compressed Sparse Row format>

# %%
X_test_dummy
# Out:
# <34606x152 sparse matrix of type '<class 'numpy.float64'>'
# 	with 228040 stored elements in Compressed Sparse Row format>

# %%
ytr.shape
# Out:
# (173026, 8)

# %%
ytr.shape
# Out:
# (173026, 8)

# %%
#linear regression
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import mean_absolute_error,r2_score


models = {
    'lr':LinearRegression(),
    'lss':Lasso(),
    'Rid':Ridge(),
    'Dtr':DecisionTreeRegressor(),
    'gbr' : GradientBoostingRegressor()
}
for name, md in models.items():
    md.fit(X_train_dummy,y_train)
    y_pred = md.predict(X_test_dummy)

    print(f"{name} : mae : {mean_absolute_error(y_test,y_pred)} score : {r2_score(y_test,y_pred)}")
# Out:
# lr : mae : 0.5007224299014673 score : 0.7892457222050975
# lss : mae : 1.295749293768331 score : -4.371020958959804e-06
# Rid : mae : 0.5009052548183999 score : 0.7892617447839931
# Dtr : mae : 0.10133018608980891 score : 0.9725177570529855
# gbr : mae : 0.31789772438227687 score : 0.9074806812831645

# %% [markdown]
# ## **Select Model**

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train_dummy,y_train)
dtr.predict(X_test_dummy)
# Out:
# array([0.19266055, 1.30769231, 2.00134807, ..., 1.69682303, 1.45      ,
#        0.24400148])

# %%
X_train
# Out:
#             State_Name Crop_Type                Crop  rainfall  temperature  \
# 122122     uttarakhand      rabi               Wheat  169.8200    14.600000
# 59473          haryana    kharif                Rice  331.8800    35.346667
# 30651      west bengal      rabi               Wheat  152.5400    22.280000
# 29995    uttar pradesh      rabi              Barley   75.3200    22.676000
# 41803    uttar pradesh    kharif             Sesamum  579.7500    34.010000
# ...                ...       ...                 ...       ...          ...
# 97639      west bengal      rabi   Moong(Green Gram)  152.5400    22.280000
# 95939          tripura      rabi  Other  Rabi pulses  145.7600    21.660000
# 152315       karnataka      rabi  Other  Rabi pulses  199.2125    21.300000
# 117952          odisha      rabi           Sugarcane  167.3800    23.560000
# 43567   andhra pradesh    kharif        Dry chillies  654.3400    29.266667
#
#         Area_in_hectares  Production_in_tons
# 122122           14320.0             20879.5
# 59473            14320.0             20879.5
# 30651              785.0              1461.0
# 29995             6125.0              9569.0
# 41803              151.0                24.0
# ...                  ...                 ...
# 97639               25.0                12.0
# 95939              305.0               177.0
# 152315             695.0               192.0
# 117952             411.0             20879.5
# 43567            14320.0             20879.5
#
# [138420 rows x 7 columns]

# %%
ytr
# Out:
#             State_Name   Crop_Type          Crop  rainfall  temperature  \
# 0       andhra pradesh      kharif     Arhar/Tur    654.34    29.266667
# 1       andhra pradesh      kharif         Bajra    654.34    29.266667
# 2       andhra pradesh      kharif   Castor seed    654.34    29.266667
# 3       andhra pradesh      kharif  Cotton(lint)    654.34    29.266667
# 4       andhra pradesh      kharif  Dry chillies    654.34    29.266667
# ...                ...         ...           ...       ...          ...
# 173021     west bengal      summer         Maize    182.50    29.200000
# 173022     west bengal      summer          Rice    182.50    29.200000
# 173023     west bengal  whole year     Sugarcane   1501.98    25.818182
# 173024     west bengal        rabi          Rice    152.54    22.280000
# 173025     west bengal        rabi       Sesamum    152.54    22.280000
#
#         Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0                14320.0              2600.0           0.121495
# 1                 1400.0               500.0           0.357143
# 2                 1000.0               100.0           0.100000
# 3                 7300.0              9400.0           1.287671
# 4                 3700.0              7100.0           1.918919
# ...                  ...                 ...                ...
# 173021             258.0               391.0           1.515504
# 173022             105.0               281.0           2.676190
# 173023             303.0             11541.0           4.859736
# 173024           14320.0             20879.5           1.712352
# 173025             244.0                95.0           0.389344
#
# [173026 rows x 8 columns]

# %%
def prediction(State_Name,Crop_Type,	Crop,	rainfall,	temperature,Area_in_hectares,Production_in_tons):
    # Create an array of the input features
    features = np.array([[State_Name,	Crop_Type,	Crop,	rainfall,	temperature,	Area_in_hectares,	Production_in_tons]], dtype=object)

    # Transform the features using the preprocessor
    transformed_features = preprocesser.transform(features)

    # Make the prediction
    predicted_yield = dtr.predict(transformed_features).reshape(1, -1)

    return predicted_yield[0]

State_Name= 'andhra pradesh'
Crop_Type= 'kharif'
Crop= 'Arhar/Tur'
rainfall= 654.34
temperature= 29.266667
Area_in_hectares= 14320.0
Production_in_tons= 2600.0

result = prediction(State_Name,Crop_Type,Crop,rainfall,temperature,	Area_in_hectares,	Production_in_tons)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([0.12149533])

# %%
import pickle
pickle.dump(dtr,open('dtr.pkl','wb'))
pickle.dump(preprocesser,open('preprocessor.pkl','wb'))

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2
